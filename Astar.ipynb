# %%
init_state = [[4, 5, 7],[6, 3, 2],[0, 1, 8]]
goal_state = [[1, 2, 3],[4, 5, 6],[7, 0, 8]]

FinalPosition = {1:(0,0),2:(0,1),3:(0,2),4:(1,0),5:(1,1),6:(1,2),7:(2,0),0:(2,1),8:(2,2)}  # 终局位置，为什么是Y轴方向向下？

def GetSpace(state):  # 找0
    for x in range(3):
        for y in range(3):
            if state[x][y] == 0: 
                return x, y


def CopyState(state):
    s = []
    for i in state: 
        s.append(i[:])
    return s

# 交换位置
def MoveUp(state):
    s = CopyState(state)
    x, y = GetSpace(s)
    s[x][y], s[x - 1][y] = s[x - 1][y], s[x][y]
    return s
def MoveDown(state):
    s = CopyState(state)
    x, y = GetSpace(s)
    s[x][y], s[x + 1][y] = s[x + 1][y], s[x][y]
    return s
def MoveLeft(state):
    s = CopyState(state)
    x, y = GetSpace(s)
    s[x][y], s[x][y - 1] = s[x][y - 1], s[x][y]
    return s
def MoveRight(state):
    s = CopyState(state)
    x, y = GetSpace(s)
    s[x][y], s[x][y + 1] = s[x][y + 1], s[x][y]
    return s

####################

def GetPossibleActions(state):
    acts = []
    x, y = GetSpace(state)
    if y > 0:acts.append(MoveLeft)
    if x > 0:acts.append(MoveUp)
    if y < 2: acts.append(MoveRight)
    if x < 2: acts.append(MoveDown)
    return acts


def NoPositionDistance(state):#计算当前state距离终局的不在位数
    dic, disorder = FinalPosition, 0
    for i in range(3):
        for j in range(3):
            pos = dic[state[i][j]]
            x, y= pos[0], pos[1]
            if x != i or y != j:
                disorder += 1
    return disorder


def Start(state):
    return


class Node:
    state = None   
    step = 0       # g值
    value = -1     # f值
    action = Start  
    parent = None,  
    def __init__(self, state, step, action, parent):#构造函数
        self.state = state
        self.step = step
        self.action = action
        self.parent = parent
        self.value = step + NoPositionDistance(state) #f=g+h，



def GetMinIndex(queue):
    index = 0
    for i in range(len(queue)):
        node = queue[i]
        if node.value < queue[index].value:
            index = i
    return index


def Hash(state):#哈希，把状态映射为一个数，判断状态是否已经搜索过
    value = 0
    for i in state:
        for j in i:
            value = value * 10 + j
    return value


def AStar(init, goal):
    queue = [Node(init, 0, Start, None)]#open队列
    closed = {}  # 访问过的状态表
    count = 0   # 搜索节点个数
    
    while queue:
        index = GetMinIndex(queue)#找到最小的启发值
        node = queue[index]
        closed[Hash(node.state)] = True
        count += 1
        if node.state == goal:
            return node, count
        del queue[index]
        
        for act in GetPossibleActions(node.state):# 扩展open列表
            neighbour = Node(act(node.state), node.step + 1, act, node)
            if Hash(neighbour.state) not in closed:
                queue.append(neighbour)
    return None, count



def reverse(node):
    if node.parent == None:
        return node, node
    head, tail = reverse(node.parent)
    tail.parent, node.parent = node, None
    return head, node


def PrintState(state):
    for i in state: 
        print(i)



node, count = AStar(init_state, goal_state)
if node == None:
    print("无法从初始状态移动到目标状态！")
else:
    print("搜索成功，一共搜索了", count, "个节点。")
    node, rear = reverse(node)
    count = 0
    while node:
        print("第", count + 1, "步：", node.action.__name__, "启发值为：", count, "+", node.value - count)
        PrintState(node.state)
        node = node.parent
        count += 1
# Out:
# 搜索成功，一共搜索了 35112 个节点。
# 第 1 步： Start 启发值为： 0 + 8
# [4, 5, 7]
# [6, 3, 2]
# [0, 1, 8]
# 第 2 步： MoveUp 启发值为： 1 + 8
# [4, 5, 7]
# [0, 3, 2]
# [6, 1, 8]
# 第 3 步： MoveUp 启发值为： 2 + 7
# [0, 5, 7]
# [4, 3, 2]
# [6, 1, 8]
# 第 4 步： MoveRight 启发值为： 3 + 7
# [5, 0, 7]
# [4, 3, 2]
# [6, 1, 8]
# 第 5 步： MoveRight 启发值为： 4 + 7
# [5, 7, 0]
# [4, 3, 2]
# [6, 1, 8]
# 第 6 步： MoveDown 启发值为： 5 + 7
# [5, 7, 2]
# [4, 3, 0]
# [6, 1, 8]
# 第 7 步： MoveLeft 启发值为： 6 + 7
# [5, 7, 2]
# [4, 0, 3]
# [6, 1, 8]
# 第 8 步： MoveDown 启发值为： 7 + 6
# [5, 7, 2]
# [4, 1, 3]
# [6, 0, 8]
# 第 9 步： MoveLeft 启发值为： 8 + 7
# [5, 7, 2]
# [4, 1, 3]
# [0, 6, 8]
# 第 10 步： MoveUp 启发值为： 9 + 8
# [5, 7, 2]
# [0, 1, 3]
# [4, 6, 8]
# 第 11 步： MoveUp 启发值为： 10 + 8
# [0, 7, 2]
# [5, 1, 3]
# [4, 6, 8]
# 第 12 步： MoveRight 启发值为： 11 + 8
# [7, 0, 2]
# [5, 1, 3]
# [4, 6, 8]
# 第 13 步： MoveDown 启发值为： 12 + 8
# [7, 1, 2]
# [5, 0, 3]
# [4, 6, 8]
# 第 14 步： MoveDown 启发值为： 13 + 7
# [7, 1, 2]
# [5, 6, 3]
# [4, 0, 8]
# 第 15 步： MoveLeft 启发值为： 14 + 8
# [7, 1, 2]
# [5, 6, 3]
# [0, 4, 8]
# 第 16 步： MoveUp 启发值为： 15 + 8
# [7, 1, 2]
# [0, 6, 3]
# [5, 4, 8]
# 第 17 步： MoveUp 启发值为： 16 + 8
# [0, 1, 2]
# [7, 6, 3]
# [5, 4, 8]
# 第 18 步： MoveRight 启发值为： 17 + 7
# [1, 0, 2]
# [7, 6, 3]
# [5, 4, 8]
# 第 19 步： MoveRight 启发值为： 18 + 6
# [1, 2, 0]
# [7, 6, 3]
# [5, 4, 8]
# 第 20 步： MoveDown 启发值为： 19 + 5
# [1, 2, 3]
# [7, 6, 0]
# [5, 4, 8]
# 第 21 步： MoveLeft 启发值为： 20 + 4
# [1, 2, 3]
# [7, 0, 6]
# [5, 4, 8]
# 第 22 步： MoveDown 启发值为： 21 + 3
# [1, 2, 3]
# [7, 4, 6]
# [5, 0, 8]
# 第 23 步： MoveLeft 启发值为： 22 + 4
# [1, 2, 3]
# [7, 4, 6]
# [0, 5, 8]
# 第 24 步： MoveUp 启发值为： 23 + 3
# [1, 2, 3]
# [0, 4, 6]
# [7, 5, 8]
# 第 25 步： MoveRight 启发值为： 24 + 2
# [1, 2, 3]
# [4, 0, 6]
# [7, 5, 8]
# 第 26 步： MoveDown 启发值为： 25 + 0
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
